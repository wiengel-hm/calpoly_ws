# %% [markdown]
# # Quick Introduction to Matplotlib and OpenCV

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# Download a sample image using wget
# !wget -O sample.jpg https://www.calpoly.edu/sites/default/files/2020-01/about-calpoly-aerial.jpg -q
# !wget -q https://cdn.abcotvs.com/dip/images/6125887_042420-kfsn-dig-ktr-complete-stop-vid.jpg -O sign.jpg

# %% [markdown]
# ## Matplotlib: Plotting with NumPy

# %%
# Generate two random point clouds
num_points = 100

# Create a scatter plot

# Labels and title

# Show the plot

# %% [markdown]
# ## Basic OpenCV operations

# %%
# Load the image using OpenCV

# Convert BGR to RGB

# Convert BGR to Grayscale

# Create a 1x3 subplot

# Display BGR image

# Display RGB image

# Display Grayscale image

# Show the plot

# %%
# Load the image

# Convert to grayscale

# Apply Canny edge detection

# Resize the image to half its original size

# Crop a portion of the image using NumPy slicing (e.g., center crop)

# Display the original, Canny edges, resized, and cropped images
