# %% [markdown]
# # Python Bascis

# %% [markdown]
# ### Variables & Basic Data Types

# %%
# Python variables: snake_case, no numbers at the start (e.g. user_name, total_sum1)

# Integer (whole number)

# Float (decimal numbers)

# Strings (text)

# Boolean (True or False)

# Type conversions

# %% [markdown]
# ### Basic Math Operations

# %% [markdown]
# ### If-Else Statements

# %% [markdown]
# ### Inline If-Else Statement

# %% [markdown]
# ### Lists

# %% [markdown]
# ### Tuples

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# ### Loops

# %% [markdown]
# #### List Comprehension

# %% [markdown]
# #### Dictionary Comprehension

# %% [markdown]
# ### Working with File Paths

# %%
from pathlib import Path

# Define a path to a directory (e.g., where our data lives)


# Inspecting directories is critical in data workflows
# Helps you understand available files before loading data


# Define a filename (e.g., dataset or config file)


# Combine directory + filename using the / operator


# This avoids manual string concatenation (which is error-prone)


# Always check before loading data to avoid runtime errors

# %% [markdown]
# ### Functions

# %%
# This is a simple function definition in Python
# The function is called 'update_position' and it takes 3 inputs: x0, v, and t


# This function is called 'update_motion' and it takes 4 inputs

# %%
# This function has default values for all its parameters
# If the caller doesn't provide a value, the default is used


# Here we call the function with two arguments: x0 = 0.0, v = 2.0
# t will use its default value (1.0)


# Now we call the function using named arguments
# We explicitly set x0 and t, and let v use the default (1.0)

# %% [markdown]
# ### Classes

# %%
# Define a base class for a generic Vehicle

# %% [markdown]
# ## Python Basics - Exercises
#
# These exercises are designed to be completed in about **two hours**.

# %% [markdown]
# ### Exercise 1: Variables & Data Types (5 minutes)
# - Create variables to represent a car's **fuel level**, **current gear**, **engine temperature**, and **battery percentage**.
# - Print their data types and convert the temperature to a string.

# %% [markdown]
# ### Exercise 2: Useful Math Operations (10 minutes)
#
# - You have 980 ml of liquid soap. Each bottle holds 250 ml. How many full bottles can you fill?
# - You have 17 pizza slices and want to share them equally among 4 people. How many slices will be left over?
# - Convert **750000000 nanoseconds** into seconds.
# - Calculate the energy using the formula:
#   $$E = m \cdot c^2$$
#   where `m = 2` and `c = 3e8`.

# %% [markdown]
# ### Exercise 3: If-Else Statements (10 minutes)
# - Write a program that checks if a car's **speed** exceeds the **speed limit**.
# - Print "Overspeeding!" if the speed is above the limit, "Under Limit" if it's below, and "At Limit" if they are equal.
# - Use `if-elif-else` for the conditions.

# %% [markdown]
# ### Exercise 4: Sensor Data Analysis (10 minutes)
#
# You receive a list of temperature readings collected every second from a sensor:
#
# ```python
# temperature_readings = [22.1, 22.3, 22.4, 22.6, 22.9, 23.0, 23.2, 23.3, 23.1, 22.8]
# ```
#
# - Print the **first 5 readings** (first 5 seconds).
# - Print the **last 3 readings** (last 3 seconds).
# - Print readings from **second 3 to second 7** (inclusive of index 2 to 6).
# - Print the full list **in reverse order** (newest first).
# - Print **every second reading**, starting from the beginning.

# %% [markdown]
# ### Exercise 5: Dictionaries & Tuples (10 minutes)
# - Create a **dictionary** storing details of a self-driving car:
#   ```python
#   car = {
#       "model": "Tesla Model S",
#       "year": 2022,
#       "sensors": ["LiDAR", "Camera", "Radar"],
#       "battery": 85.0  # kWh
#   }
#   ```
# - Add a new key `"autonomy_level"` with value `3`.
# - Print the keys and values in the dictionary.

# %% [markdown]
# ### Exercise 6: Lists & Loops (10 minutes)
# - Given a list of **sensor distances**: `[0.5, 1.0, 1.5, 0.2, 0.8]`.
#   - Convert each value to **centimeters** using a loop.
#   - Filter out values below **50 cm** and print the filtered list.
# - Use a list comprehension to do the same task.

# %% [markdown]
# ### Exercise 7: File Paths & Directory Operations (10–15 minutes)
#
# * Use the directory `/content/sample_data` and define a `Path` object for it
# * Define a path to `README.md` and check if it exists (print a message if it does not)
# * List all files in the directory and print their names
# * Given the list `["README.md", "anscombe.json", "california_housing_train.csv", "does_not_exist.csv"]`, use a list comprehension to combine each filename with the directory path
# * Print the resulting list of full paths
# * Loop over all paths and check if each file exists (print a warning for missing files)

# %% [markdown]
# ### Exercise 8: Functions (15 minutes)
# - Define a function `convert_to_radians(degrees)` that converts angles from degrees to radians.
# - Use a list of angles `[0, 30, 45, 60, 90, 120, 180]` and apply your function to each angle.
# - Return the results as a **list** and print it.

# %% [markdown]
# ### Exercise 9: Classes & Inheritance – Rectangle & Square (15 minutes)
# - Define a class `Rectangle` with attributes `width` and `height`.
# - Add methods `area()` and `perimeter()` that return the area and perimeter of the rectangle.
# - Define a subclass `Square` that inherits from `Rectangle`. It should only take one argument `side_length` and use it for both width and height.
# - Create one `Rectangle` and one `Square` object and print their area and perimeter.

# %% [markdown]
# ### Exercise 10: Classes – Library System (20 minutes)
# - Define a class `Book` with attributes `title` and `author`.
# - Define a class `Library` that stores a list of books.
# - Implement the following methods in `Library`:
#   - `add_book(book)` – adds a `Book` to the collection
#   - `borrow_book(title)` – removes the book with the given title if available
#   - `return_book(book)` – adds the book back to the library
#   - `list_available_books()` – prints all books currently in the library
# - Test your system by adding 3 books, borrowing one, listing the available books, and returning it.
