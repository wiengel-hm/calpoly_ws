# %% [markdown]
# <font size="10" color="DarkSlateGray"><b>Ultralytics Object Detection</b></font>
#
# <img src="https://drive.google.com/uc?export=view&id=1u71bvuqnuzD8EgT6Jqq6frWwM7W1PnHP" width="1000">

# %%
# Install YOLO and Roboflow
# !pip install -qq ultralytics==8.3.119 roboflow >/dev/null 2>&1

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from IPython.core.magic import register_cell_magic

@register_cell_magic
def skip(line, cell):
    pass # Do nothing → skips execution

# %% [markdown]
# ## YOLO11 Model Guide

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/ultralytics/assets@main/docs/ultralytics-yolov8-tasks-banner.avif
# " width="1000">

# %% [markdown]
# YOLO11 supports multiple computer vision tasks. Choose a task type and model size based on your needs.
#
# ---
#
# ### Task Types
#
# **Detection** `yolo11`
# Locates and draws bounding boxes around objects in images
#
# **Segmentation** `yolo11-seg`
# Identifies precise pixel-level object boundaries and shapes
#
# **Classification** `yolo11-cls`
# Assigns a single category label to an entire image
#
# **Pose Estimation** `yolo11-pose`
# Detects human body keypoints for pose and skeleton tracking
#
# **Oriented Detection** `yolo11-obb`
# Detects objects with rotated bounding boxes (non-axis-aligned)
#
# ---
#
# ### Model Sizes
#
# **n (Nano)** — Fastest, basic accuracy → Mobile and edge devices
# **s (Small)** — Fast, good accuracy → Real-time applications
# **m (Medium)** — Moderate speed, better accuracy → Balanced performance
# **l (Large)** — Slow, high accuracy → Accuracy over speed
# **x (Extra)** — Slowest, highest accuracy → Maximum accuracy requirements
#
# ---
#
# ### Usage
#
# Combine task prefix and size to load your model:
# ```python
# from ultralytics import YOLO
#
# # Format: {task}{size}.pt
# model = YOLO("yolo11s.pt")          # Small detection
# model = YOLO("yolo11m-seg.pt")      # Medium segmentation
# model = YOLO("yolo11l-pose.pt")     # Large pose estimation
# ```
#
# **Naming pattern:** `{task}{size}.pt` (e.g., `yolo11m-seg.pt`)

# %% [markdown]
# ## Connections

# %%
import os
from google.colab import drive, userdata
from pathlib import Path

# %% [markdown]
# **Connect to Google Drive**

# %%
# Connect to Google Drive
if not Path("/content/drive").exists():
  drive.mount("/content/drive")

# Update 'base_dir' with the path to your private workspace on Google Drive
base_dir = Path("/content/drive/MyDrive/00_Workspace")

if not base_dir.exists():
  raise FileNotFoundError(f"Base directory {base_dir} does not exist")

# Define model directory
model_dir = base_dir / "models"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download Dataset from Roboflow

# %%
ROBOFLOW_KEY = userdata.get('ROBOFLOW_KEY')

HOME = '/content'
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

workspace_id = "calpoly"
project_id = "roadvision-ai-revkw"
VERSION = 9

rf = Roboflow(api_key=ROBOFLOW_KEY)
project = rf.workspace(workspace_id).project(project_id)
version = project.version(VERSION)
dataset = version.download("yolov11")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in RoadVision-AI-9 to yolov11:: 100%|██████████| 99957/99957 [00:01<00:00, 65582.42it/s]
# Extracting Dataset Version Zip to RoadVision-AI-9 in yolov11:: 100%|██████████| 5847/5847 [00:00<00:00, 7585.39it/s]

# %% [markdown]
# ## Train Model

# %%
# Load a pretrained YOLOv11 segmentation model (small, good trade-off)
model = YOLO("yolo11s-seg.pt")

# Train the model on your Roboflow-exported dataset
# - data.yaml comes from Roboflow
# - epochs controls how long the model trains
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=120,
    project=model_dir,

    # Augmentation
    translate=0.1,
    fliplr=0.0
)

# Run validation on the validation split
# Prints mAP, precision, recall, and saves plots
model.val(verbose=False)

# %% [markdown]
# ## Resume Training

# %% [markdown]
# Use this when Colab disconnected and you want to continue the same training with the same data and settings.

# %%
# Print all files/folders (choose your run name from here, e.g., "train", "train1", "train2", etc.)
for item in model_dir.iterdir():
    print(item)

# %%
# %%skip # remove to run
#
# # Set run name (training folder)
# run_name = "train"
#
# # Load the last saved checkpoint from the old training run
# model_path = model_dir / run_name / "weights" / "last.pt"
#
# # Continue the same training run
# results = model.train(
#     data=f"{dataset.location}/data.yaml",
#     resume=True,
# )

# %% [markdown]
# ## Build on a Previously Trained Model

# %% [markdown]
# Use this when you want to start a new training with new classes, new data, or new settings.

# %%
# %%skip # remove to run
#
# # Set run name (training folder)
# run_name = "train"
#
# # Load the last saved checkpoint from the old training run
# model_path = model_dir / run_name / "weights" / "last.pt"
#
# # Load the model structure
# model = YOLO("yolo11s-seg.yaml")
#
# # Start a new training run, but reuse old weights
# results = model.train(
#     data=f"{dataset.location}/data.yaml",
#     pretrained=model_path,
#     epochs=60,
#     name="train_next", # model and results will be stored in a folder with this name
#     resume=False
#
#     # Augmentation
#     fliplr=0.0
# )

# %% [markdown]
# ## Evaluation

# %%
# Print all files/folders (choose your run name from here, e.g., "train", "train1", "train2", etc.)
for item in model_dir.iterdir():
    print(item)

# %%
# Set run name (training folder)
run_name = "train"

# Build path to best model weights
model_path = model_dir / run_name / "weights" / "best.pt"

# Load YOLO model
model = YOLO(model_path)

# %%
# Path to test images folder
test_dir = Path(f"{dataset.location}/test/images")

# Get all image file paths
im_paths = [fpath for fpath in test_dir.iterdir()]

# Load images with OpenCV
images = [cv2.imread(path) for path in im_paths]

# %%
# Run predictions on first 10 images and display results
for img in images[:10]:
    results = model(img)                  # Predict on image
    annotated = results[0].plot()         # Draw detections
    plt.imshow(annotated)                 # Show image
    plt.axis("off")                       # Hide axes
    plt.show()
# Out:
# 0: 640x640 1 end_speed_limit, 1 hood, 1 traffic_light_green, 1 traffic_light_yellow, 13.8ms
# Speed: 2.3ms preprocess, 13.8ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 1 hood, 1 line_left, 1 line_right, 1 preceding_car, 26.9ms
# Speed: 3.3ms preprocess, 26.9ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 1 hood, 1 stop_sign, 57.2ms
# Speed: 4.5ms preprocess, 57.2ms inference, 9.7ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 1 hood, 1 line_left, 1 line_right, 1 traffic_light_green, 35.6ms
# Speed: 8.7ms preprocess, 35.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 1 hood, 1 speed_limit_5, 36.7ms
# Speed: 7.6ms preprocess, 36.7ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 1 hood, 1 speed_limit_5, 21.2ms
# Speed: 2.3ms preprocess, 21.2ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 1 hood, 33.4ms
# Speed: 7.2ms preprocess, 33.4ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 1 hood, 1 line_left, 1 line_right, 1 speed_limit_5, 24.5ms
# Speed: 8.2ms preprocess, 24.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 1 hood, 1 speed_limit_5, 43.1ms
# Speed: 2.8ms preprocess, 43.1ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 1 hood, 1 no_entry, 34.3ms
# Speed: 3.3ms preprocess, 34.3ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 640)
